# %% [markdown]
# <a href="https://colab.research.google.com/github/bogdanbabych/experiments_NLTK/blob/main/download_guttenberg_corpus_v01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -w 2 -m -H "http://www.gutenberg.org/robot/harvest?filetypes[]=txt"
# Out:
# Streaming output truncated to the last 5000 lines.
# Length: 53255 (52K) [application/zip]
# Saving to: ‘aleph.gutenberg.org/1/3/0/1309/1309.zip’
#
# aleph.gutenberg.org 100%[===================>]  52.01K  --.-KB/s    in 0.1s
#
# 2023-06-23 16:51:05 (382 KB/s) - ‘aleph.gutenberg.org/1/3/0/1309/1309.zip’ saved [53255/53255]
#
# --2023-06-23 16:51:07--  http://aleph.gutenberg.org/1/4/3/1434/1434.zip
# Reusing existing connection to aleph.gutenberg.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 152064 (148K) [application/zip]
# Saving to: ‘aleph.gutenberg.org/1/4/3/1434/1434.zip’
#
# aleph.gutenberg.org 100%[===================>] 148.50K   708KB/s    in 0.2s
#
# 2023-06-23 16:51:07 (708 KB/s) - ‘aleph.gutenberg.org/1/4/3/1434/1434.zip’ saved [152064/152064]
#
# --2023-06-23 16:51:09--  http://aleph.gutenberg.org/1/5/3/6/15365/15365-8.zip
# Reusing existing connection to aleph.gutenberg.org:80.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !tar cvzf aleph-gutenberg-org.tgz aleph.gutenberg.org/
